# %% [markdown]
# # Assignment Netwerkanalyse

# %% [markdown]
# ## Notebook made by
#
# **Gebruik graag dit formaat**
#
# * Voor de namen:  voornaam rest van je naam, voornaam rest van je naam,....
# * je studentnummers: hetzelfde: scheidt met `,`
# * je emails: hetzelfde: scheidt met `,`
# * voor je groep: alleen de hoofdletter (dus voor de groep van Marx zou je `A` kiezen)
#
# __Namen__:Anoniem
# __Emails__:Anoniem
# __Student id__:Anoniem
# __Groep__:Anoniem

# %% [markdown]
# ## Toelichting
#
# * De meeste opgaven worden automatisch nagekeken. Bij vrijwel alle opdrachten staan er een paar tests onder de opdracht, dit is voornamelijk om te zorgen dat je de juiste type output geeft. Dit zijn dus *NIET* alle tests, die komen er bij het graden nog bij.
# * Elke vraag is 1 punt waard, tenzij anders aangegeven. Soms is die punt onderverdeeld in deelpunten, maar niet altijd.
#
# ## Voor het inleveren!
#
# * Pas niet de cellen aan, vooral niet die je niet kunt editen. Dit levert problemen op bij nakijken. Twijfel je of je per ongeluk iets hebt gewijzigd, kopieer dan bij inleveren je antwoorden naar een nieuw bestand, zodat het niet fout kan gaan.
#
# * Zorg dat de code goed runt van boven naar beneden, verifieer dat door boven in Kernel -> Restart & Run All uit te voeren
#
# ## Na het inleveren!
#
# * Het gebeurt erg vaak dat mensen een "leeg bestand" inleveren. Vaak een andere versie van de opgave die nog ergens op je computer rondslingerde. Zonde van al je werk toch!
# * Dus, lever **minstens een half uur voor tijd in**. Download dan wat je hebt ingeleverd op Canvas. Geef het een andere naam om verwarring te voorkomen. En draai alle cellen, en bekijk het. Geen syntax fouten? Alle vragen gemaakt? Dan zit het vast wel goed, en hoef je niet in de zenuwen te zitten.

# %% [markdown]
# # Week 3
# * Alle vragen zijn één punt waard

# %%
# %matplotlib inline
import networkx as nx
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from nose.tools import assert_equal, assert_count_equal

# %% [markdown]
# # Deel 1: First Course Chap 2
#
# * Maak vragen 1-40
#
# ### Ook met programmeren
#
# * Check je antwoorden op vragen 8-11 door het gerichte netwerk te programmeren, en alle vragen ook te programmeren in Networkx.
# * Zet de netwerken in Fig 2-13 en 2.14 in Networkx, probeer ze ook zo mooi uit te printen (zie assignment week 2), en check je antwoorden op de vragen erover.
# * Als je het leuk vindt kan je dit ook met de andere voorbeelden doen. Je weet dan wel zeker dat je het goed hebt.
#     * Op het tentamen mag je ook programmeren.....

# %% [markdown]
# # Deel 2: Easley & Kleinberg Chapter 13
#
# De volgende vragen hebben betrekking op [hoofdstuk 13 van Easley and Kleinberg](http://www.cs.cornell.edu/home/kleinber/networks-book/networks-book-ch13.pdf). Hieronder staat de networkx graaf gebaseerd op figuur 13.8, pas deze vooral aan om te zorgen dat je functies altijd werken.

# %% [markdown]
# **2.1 Chapter 1 Tutorial - Exercise 1** G.has_edge('IND', 'FAI')
#
# **2.1 Chapter 1 Tutorial - Exercise 2** nx.shortest_path(G, 'IND', 'FAI')
#
# **2.1 Chapter 1 Tutorial - Exercise 3** nx.is_connected(G)
#
# **2.2** True
#
# **2.3** True
#
# **2.4** N-1 is the minimal amount of links if the network is connected, otherwise it can't be connected. If the network is not connected then it would also be possible to have 0 links.
#
# **2.5** True
#
# **2.6** True
#
# **2.7** True
#
# **2.8** The adjacency contains a cycle (D>E>F>D>...). The network is not strongly connected (C is a sink and you can't go anywhere from this node).
#
# **2.9** No this network is not a tree because it contains cycles.
#
# **2.10** d(A,B) = 1, d(A,C) = 2, d(A,D) = 2, d(A,E) = 2, d(A,F) = 1, d(B,C) = 1, d(B,D) = 1, d(B,E) = 2, d(B,F) = 1, d(C,D) = 2, d(C,E) = 2, d(C,F) = 1, d(D,E) = 1, d(D,F) = 1, d(E,F) = 1 The diameter is the longest shortest path, which is 2 in this case.
#
# **2.11** Yes, it will be connected. Because being weakly connected in a directed network means that every node is reachable, but not in every direction. If it is converted into a undirected network, directions won't matter anymore and every node will be reachable in the network, therefore being connected.
#
# **2.12** C
#
# **2.13** B
#
# **2.14** The in-strength of node D is 9 + 2 = 11 and the out-strength of node C is 3.
#
# **2.15** 6 nodes.
#
# **2.16** B
#
# **2.17** The path 1>2>4>6 gives the shortest distance: 0.8 + 0.9 + 0.3 = 2.0
#
# **2.18** The path 1>3>5>6 gives the shortest distance: 1/0.6 + 1/0.5 + 1/0.95 = 4.72
#
# **2.19** C
#
# **2.20** A
#
# **2.21** No, a social network would have a lower diameter and higher clustering average because the nodes are closer to each other (lower diameter) and there are a lot of triangles (higher clustering).
#
# **2.22** A
#
# **2.23** -
#
# **2.24** 2
#
# **2.25** False
#
# **2.26** C
#
# **2.27** True
#
# **2.28** D
#
# **2.29** -
#
# **2.30** -
#
# **2.31** -
#
# **2.32** 1
#
# **2.33** 0
#
# **2.34** 3/10
#
# **2.35** (1,2) = 1, (1,3) = 2, (1,4) = 2, (1,5) = 3, (1,6) = 3, (1,7) = 4, (1,8) = 4, (2,3) = 1, (2,4) = 1, (2,5) = 2, (2,6) = 2, (2,7) = 3, (2,8) = 3, (3,4) = 1, (3,5) = 1, (3,6) = 1, (3,7) = 2, (3,8) = 2, (4,5) = 2, (4,6) = 2, (4,7) = 3, (4,8) = 3, (5,6) = 2, (5,7) = 2, (5,8) = 2, (6,7) = 1, (6,8) = 1, (7,8) = 2
#
# **2.36** 1 = 0, 2 = 1/3, 3 = 1/6, 4 = 1, 5 = 0, 6 = 0, 7 = 0, 8 = 0
#
# **2.37**
# **2.38**
# **2.39** -
# **2.40** A

# %%
G = nx.DiGraph()
G.add_weighted_edges_from([("A", "B", 1), ("B", "C", 2), ("D", "B", 1), ("D", "E", 1), ("E", "F", 1), ("F", "A", 2), ("F", "B", 1), ("F", "C", 3), ("F", "D", 1), ("F", "E", 1)])
pos=nx.spring_layout(G)
nx.draw_networkx(G,pos)
labels = nx.get_edge_attributes(G,'weight')
nx.draw_networkx_edge_labels(G,pos,edge_labels=labels)
# Out:
# {('A', 'B'): Text(-0.1319609919073779, -0.2930530167852665, '1'),
#  ('B', 'C'): Text(-0.3961404724970931, -0.6522405818712396, '2'),
#  ('D', 'B'): Text(0.407733646050465, -0.3464854899520749, '1'),
#  ('D', 'E'): Text(0.5288592004960464, 0.5635226405240823, '1'),
#  ('E', 'F'): Text(0.130823612747544, 0.4717628276562668, '1'),
#  ('F', 'A'): Text(-0.13271872799895293, 0.08871794134715744, '2'),
#  ('F', 'B'): Text(0.009698058301962569, -0.4382453028198903, '1'),
#  ('F', 'C'): Text(-0.39689820858866814, -0.27046962373881556, '3'),
#  ('F', 'D'): Text(0.40697590995889, 0.03528546818034907, '1'),
#  ('F', 'E'): Text(0.130823612747544, 0.4717628276562668, '1')}

# %%
# Question 2.8
print("Question 2.8:")
print(nx.find_cycle(G))
print(nx.is_strongly_connected(G))
print(nx.is_weakly_connected(G))
# Out:
# Question 2.8:
# [('D', 'E'), ('E', 'F'), ('F', 'D')]
# False
# True

# %%
# Figure 2.13
G3 = nx.DiGraph()
G3.add_weighted_edges_from([("A", "B", 2), ("A", "C", 6), ("B", "C", 1), ("B", "D", 9), ("B", "F", 11), ("C", "E", 3),  ("D", "F", 2), ("E", "D", 2)])
pos=nx.spring_layout(G3)
nx.draw_networkx(G3, pos)
labels = nx.get_edge_attributes(G3,'weight')
nx.draw_networkx_edge_labels(G3,pos,edge_labels=labels)
# Out:
# {('A', 'B'): Text(0.07239281523730492, -0.04484317283509262, '2'),
#  ('A', 'C'): Text(0.12054138207542825, 0.6889782282164192, '6'),
#  ('B', 'C'): Text(0.05124328676988091, 0.22176573038758568, '1'),
#  ('B', 'D'): Text(-0.07943080610077824, -0.42187569619881815, '9'),
#  ('B', 'F'): Text(0.002604602185686127, -0.756027835331963, '11'),
#  ('C', 'E'): Text(0.007528108609544698, 0.7106910337019476, '3'),
#  ('D', 'F'): Text(-0.07992092384684969, -0.6658478608668551, '2'),
#  ('E', 'D'): Text(-0.12314598426111445, 0.06704960711554384, '2')}

# %%
print("Question 2.13:")
print(nx.is_weakly_connected(G3))

print("Question 2.15:")
print(nx.number_strongly_connected_components(G3))
# Out:
# Question 2.13:
# True
# Question 2.15:
# 6

# %%
# Figure 2.14
G4 = nx.DiGraph()
G4.add_weighted_edges_from([(1, 2, 0.8), (1, 3, 0.6), (2, 4, 0.9), (3, 5, 0.5), (4, 6, 0.3), (4, 5, 0.8), (5, 6, 0.95)])
pos = nx.spring_layout(G4)
nx.draw_networkx(G4, pos)
labels = nx.get_edge_attributes(G4,'weight')
nx.draw_networkx_edge_labels(G4,pos,edge_labels=labels)
# Out:
# {(1, 2): Text(0.19986187133580252, -0.5035816816934372, '0.8'),
#  (1, 3): Text(0.6803834086315547, -0.1461256888513699, '0.6'),
#  (2, 4): Text(-0.06359864014604293, -0.2325216927619952, '0.9'),
#  (3, 5): Text(0.27338346854547324, 0.23498840517472697, '0.5'),
#  (4, 6): Text(-0.4732453398812762, 0.2685932765187102, '0.3'),
#  (4, 5): Text(-0.09003010836678835, 0.145589427230707, '0.8'),
#  (5, 6): Text(-0.6167847684855121, 0.37864738161336503, '0.95')}

# %%
print("Question 2.16:")
print(nx.is_weakly_connected(G4))
# Out:
# Question 2.16:
# True

# %%
EK = nx.DiGraph()
EK.add_edges_from([(6, 2), (6, 7), (7, 8), (11, 7), (1, 8), (12, 13), (8, 13),
                   (18, 13), (15, 18), (15, 14), (13, 14), (14, 9), (9, 3),
                   (3, 8), (4, 1), (4, 5), (5, 10), (16, 10), (17, 16), (15,
                                                                         16),
                   (9, 4), (9, 15)])

nx.draw_circular(EK, with_labels=True)

# %% [markdown]
# ## Vraag 5
#
# * Maak een functie `find_SCC` die gegeven een gerichte graaf een set teruggeeft met daarin alle nodes die behoren tot de grootste SCC (strongly connected component).
#
# * Maak een functie `find_IN` die gegeven een gerichte graaf een set teruggeeft met daarin alle nodes die behoren tot de IN (dat zijn alle knopen met een pad naar de SCC, maar vanuit de SCC kan je niet naar die knopen komen).
#
# * Maak een functie `find_OUT` die gegeven een gerichte graaf een set teruggeeft met daarin alle nodes die behoren tot de OUT (ja, dit snap je nu zelf wel hoop ik).

# %%
def find_SCC(G):
    return set(max(nx.strongly_connected_components(G), key=len))

def find_IN(G):
    NoSCC = set(G.nodes) - find_SCC(G)
    return {x for x in NoSCC for y in find_SCC(G) if nx.has_path(G, x, y)}
    
    
def find_OUT(G):
    NoSCC = set(G.nodes) - find_SCC(G)
    return {x for x in NoSCC for y in find_SCC(G) if nx.has_path(G, y, x)}
    

# even testen op figuur 13.8 uit het boek
find_SCC(EK), find_IN(EK), find_OUT(EK)
# Out:
# ({1, 3, 4, 8, 9, 13, 14, 15, 18}, {6, 7, 11, 12}, {5, 10, 16})

# %%
assert_equal(type(find_SCC(EK)), set)
assert_equal(type(find_OUT(EK)), set)
assert_equal(type(find_IN(EK)), set)
assert find_SCC(EK).issubset(EK.nodes())
assert find_IN(EK).issubset(EK.nodes())
assert find_OUT(EK).issubset(EK.nodes())

# %%
# resultaat graaf tekenen
def draw_web(G):
    pos = nx.spring_layout(G)
    nx.draw(G, pos, with_labels=True)
    color = sns.color_palette("hls", 7)
    #tubes = find_tubes(G)
    legenda = [
        'SCC', 'IN', 'OUT', ] #'Tendrils (IN)', 'Tendrils (OUT)', 'Tubes','Disconnected' ]
    listofnodes = [
        find_SCC(G),
        find_IN(G),
        find_OUT(G),
        #find_tendrils_IN(G) - tubes,
        #find_tendrils_OUT(G) - tubes, tubes,
        #find_disconnected(G)
    ]
    for n, (label, nodes, c) in enumerate(zip(legenda, listofnodes, color)):
        nx.draw_networkx_nodes(
            G, pos, nodelist=nodes, node_color=[c], label=label)
    nx.draw_networkx_edges(G, pos)
    plt.legend()
    plt.axis('off')
    plt.show()


draw_web(EK)

# %% [markdown]
# # Deel 3: Clustering coëfficiënt

# %%
G = nx.karate_club_graph()

nx.draw(G, with_labels=True)

# %% [markdown]
# ## Vraag 3.1
# Maak een functie `clusteringcoefficient(G)` die een graaf accepteert als input, en voor alle knopen de clusteringcoëfficiënt ([Sectie 3.1 E&amp;K](http://www.cs.cornell.edu/home/kleinber/networks-book/networks-book-ch03.pdf)) berekent.
#
# <strong>Bereken dit zelf, gebruik geen NetworkX functie die dit al doet zoals `clustering` en `average_clustering`. </strong> Je mag natuurlijk wel NetworkX handigheidjes als `G.neighbors(v)` gebruiken.
#
# Als output krijg je een dict  met de knopen van `G` als sleutels en de clustering coeffiecient van die knoop als bijbehorende waarde.   Geef waarde 0 als een knoop degree 1 heeft.
#
#
# De verwachte output voor deze graaf is 1 voor knoop 7 en 2/3 voor knoop 3 en 0 voor knoop 11. etc.

# %%
def cc(G,x):
    neighbors = list(G.neighbors(x))
    if len(neighbors) == 1:
        return 0.0
    else:
        graaf = G.subgraph(neighbors)
        teller = len(graaf.edges())
        N = graaf.number_of_nodes()
        noemer = N * (N - 1) / 2
        return teller / noemer

def clusteringcoefficient(G):        
    return {x: (cc(G, x)) for x in G}    

# even er een mooi plotje van maken
pd.Series( clusteringcoefficient(G) ).sort_values().plot(kind='barh',figsize=(8,8))

clusteringcoefficient(G)
# Out:
# {0: 0.15,
#  1: 0.3333333333333333,
#  2: 0.24444444444444444,
#  3: 0.6666666666666666,
#  4: 0.6666666666666666,
#  5: 0.5,
#  6: 0.5,
#  7: 1.0,
#  8: 0.5,
#  9: 0.0,
#  10: 0.6666666666666666,
#  11: 0.0,
#  12: 1.0,
#  13: 0.6,
#  14: 1.0,
#  15: 1.0,
#  16: 1.0,
#  17: 1.0,
#  18: 1.0,
#  19: 0.3333333333333333,
#  20: 1.0,
#  21: 1.0,
#  22: 1.0,
#  23: 0.4,
#  24: 0.3333333333333333,
#  25: 0.3333333333333333,
#  26: 1.0,
#  27: 0.16666666666666666,
#  28: 0.3333333333333333,
#  29: 0.6666666666666666,
#  30: 0.5,
#  31: 0.2,
#  32: 0.19696969696969696,
#  33: 0.11029411764705882}

# %%
assert isinstance(clusteringcoefficient(G), dict)
for n in clusteringcoefficient(G):
    assert n in G
    assert isinstance(clusteringcoefficient(G)[n],float)

# %% [markdown]
# ## Vraag 3.1.1
#
# Maak de functie `cc_nice(G, v)` nu nog een keer maar gebruik nu alleen maar `G.has_edge()` van networkx.
# Chack dat hij echt hetzelfde doet als je eerdere functie en als networkx clustering.

# %%
def cc_nice(G,v):
    neighbors = list(G.neighbors(v))
    if len(neighbors) == 1:
        return 0.0
    else:
        graaf = G.subgraph(neighbors)
        teller = len(graaf.edges())
        N = graaf.number_of_nodes()
        noemer = N * (N - 1) / 2
        return teller / noemer

# check dat de twee functies hetzelfde resultaat geven voor elke knoop op de karateclub
all(cc(G,n)==cc_nice(G,n) for n in G)
# Out:
# True

# %% [markdown]
# ## Vraag 3.1.2
#
# Maak de functie `cc_nicer(G, v)` nu nog een keer maar gebruik nu alleen maar  `G.subgraph` en `nx.density` van networkx.
# Check dat hij echt hetzelfde doet als je eerdere functie en als networkx clustering.

# %%
def cc_nicer(G,v):
    neighbors = list(G.neighbors(v))
    if len(neighbors) == 1:
        return 0.0
    else:
        return nx.density(G.subgraph(neighbors))
        

# check dat de twee functies hetzelfde resultaat geven voor elke knoop op de karateclub
all(cc(G,n)==cc_nicer(G,n) for n in G)
# Out:
# True

# %% [markdown]
# ## Vraag 3.2
#
# 2. Maak de functie  `is_complete(G)`  die `True` teruggeeft precies dan als het ongerichte netwerk  `G` een volledig netwerk is en `False` als dat niet het geval is.  Gebruik **alleen** de networkx functies `nx.number_of_nodes(G)` en `G.number_of_edges()`.

# %%
def is_complete(G):
    nodes = nx.number_of_nodes(G)
    edges = G.number_of_edges()
    volledig = nodes * (nodes - 1)
    return True if edges == volledig else False
is_complete(G)
# Out:
# False

# %%
assert isinstance(is_complete(G), bool)
